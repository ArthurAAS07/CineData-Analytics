# %% [markdown]
# # CineData Analytics — Silver to Gold
#
# Este notebook é responsável pela construção da camada Gold do projeto.
#
# Nesta etapa são desenvolvidos:
#
# - modelo dimensional em Star Schema;
# - dimensões e tabela fato;
# - tabelas-ponte para relacionamentos muitos-para-muitos;
# - chaves substitutas (Surrogate Keys);
# - tabela de contexto para aplicações de IA Generativa e RAG;
# - consultas analíticas para responder às perguntas de negócio.

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

spark.sql("USE CATALOG workspace")
spark.sql("CREATE SCHEMA IF NOT EXISTS gold")
# Out:
# DataFrame[]
